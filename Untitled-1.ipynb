# %%
import pandas as pd

# %%
df = pd.read_csv('toucans_rarity.csv')

# %%
df = df.sort_values(by=["mean_trait_rarity"], ascending=False)

# %%
df = df.reset_index()

# %%
df['rarity'] = df.index

# %%
df.name.str.split('#')
# Out:
# 0       [Toucan Gang , 2391]
# 1       [Toucan Gang , 7366]
# 2       [Toucan Gang , 4118]
# 3        [Toucan Gang , 626]
# 4       [Toucan Gang , 4526]
#                 ...
# 7714                     NaN
# 7715                     NaN
# 7716                     NaN
# 7717                     NaN
# 7718                     NaN
# Name: name, Length: 7719, dtype: object

# %%
df
# Out:
#       index  Unnamed: 0               name    Eyes  Plumage     Beak  Hat  \
# 0      3049           0  Toucan Gang #2391     NaN  Regular  Regular  NaN
# 1      3539           0  Toucan Gang #7366     NaN  Regular  Regular  NaN
# 2      3846           0  Toucan Gang #4118  Stoner  Regular  Regular  NaN
# 3      6456           0   Toucan Gang #626  Crying  Regular  Regular  NaN
# 4      7467           0  Toucan Gang #4526    Scar  Regular  Regular  NaN
# ...     ...         ...                ...     ...      ...      ...  ...
# 7714   5621           0                NaN     NaN      NaN      NaN  NaN
# 7715   5622           0                NaN     NaN      NaN      NaN  NaN
# 7716   5628           0                NaN     NaN      NaN      NaN  NaN
# 7717   5764           0                NaN     NaN      NaN      NaN  NaN
# 7718   5765           0                NaN     NaN      NaN      NaN  NaN
#
#      Clothes Accessories  trait_n  ...  Plumage_rarity  Beak_rarity  \
# ...
